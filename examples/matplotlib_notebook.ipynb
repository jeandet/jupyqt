# %% [markdown]
# # Matplotlib in jupyqt
#
# The inline backend is auto-configured — just import and plot.

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 2 * np.pi, 200)
plt.plot(x, np.sin(x), label="sin")
plt.plot(x, np.cos(x), label="cos")
plt.legend()
plt.title("Simple trig plot")
plt.show()

# %%
fig, axes = plt.subplots(1, 3, figsize=(12, 3))
for ax, func in zip(axes, [np.sin, np.cos, np.tan]):
    ax.plot(x, func(x))
    ax.set_title(func.__name__)
    ax.set_ylim(-2, 2)
fig.tight_layout()
plt.show()

# %%
rng = np.random.default_rng(42)
plt.scatter(rng.normal(size=200), rng.normal(size=200), alpha=0.5)
plt.title("Random scatter")
plt.show()

# %% [markdown]
# ## Qt backend — native figure windows
#
# Switch to the jupyqt Qt backend to open interactive figure windows
# with zoom, pan, and save toolbar.

# %%
import matplotlib
matplotlib.use("module://jupyqt.matplotlib.backend")

# %%
plt.figure()
plt.plot(x, np.sin(x) * np.exp(-x / 5), label="damped sine")
plt.legend()
plt.title("Native Qt window")
plt.show()

# %% [markdown]
# ## Using `display()` directly
#
# Rich objects like HTML also render inline.

# %%
from IPython.display import display, HTML

display(HTML("<h3 style='color: steelblue;'>Rich HTML from display()</h3>"))
